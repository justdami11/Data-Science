# %%
import pandas as pd

# %%
df = pd.read_csv("./Covid_stats_Jan2025.csv")

# %%
df
#df.describe()
# Out:
#       Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0               USA  111,820,082       NaN   1,219,487        NaN
# 1             India   45,035,393       NaN     533,570        NaN
# 2            France   40,138,560       NaN     167,642        NaN
# 3           Germany   38,828,995       NaN     183,027        NaN
# 4            Brazil   38,743,918       NaN     711,380        NaN
# ..              ...          ...       ...         ...        ...
# 226         Tokelau           80       NaN         NaN        NaN
# 227    Vatican City           29       NaN         NaN        NaN
# 228  Western Sahara           10       NaN           1        NaN
# 229      MS Zaandam            9       NaN           2        NaN
# 230          Total:  704,753,890       0.0   7,010,681        0.0
#
#     TotalRecovered  NewRecovered ActiveCases Serious,Critical  \
# 0      109,814,428           NaN     786,167              940
# ...

# %%
# Correct way
df_stats = df[["Country,Other","TotalCases", "TotalDeaths", "TotalRecovered"]]
df_stats
# Out:
#       Country,Other   TotalCases TotalDeaths TotalRecovered
# 0               USA  111,820,082   1,219,487    109,814,428
# 1             India   45,035,393     533,570            NaN
# 2            France   40,138,560     167,642     39,970,918
# 3           Germany   38,828,995     183,027     38,240,600
# 4            Brazil   38,743,918     711,380     36,249,161
# ..              ...          ...         ...            ...
# 226         Tokelau           80         NaN            NaN
# 227    Vatican City           29         NaN             29
# 228  Western Sahara           10           1              9
# 229      MS Zaandam            9           2              7
# 230          Total:  704,753,890   7,010,681    675,619,811
#
# [231 rows x 4 columns]
